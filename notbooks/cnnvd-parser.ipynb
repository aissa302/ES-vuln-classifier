# %%
# -*- coding: utf-8 -*-
import sys
defult_encoding = 'utf-8'
if sys.getdefaultencoding() != defult_encoding:
    reload(sys)
    sys.setdefaultencoding(defult_encoding)
import requests
from bs4 import BeautifulSoup
import traceback
import re
import xlwt

list4 = []
list5 = []
list6 = []
list7 = []
list8 = []
list9 = []
list10 = []
list11 = []
list12 = []
list13 = []
list14 = []
list15 = []

def getURLDATA(url):
    global list4,list5,list6,list7,list8,list9,list10,list11,list12,list13,list14,list15
    header = {
        'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/58.0.3029.110 Safari/537.3',
        'Connection': 'keep-alive'}
    r = requests.get(url, headers=header)
    html = BeautifulSoup(r.content.decode(), 'html.parser')
    link = html.find(class_= 'detal_xq w770')
    link_introduce = html.find(class_ = 'd_ldjj')
    link_others = html.find(class_ = 'd_ldjj m_t_20')

    try:
        list4.append(str(link.contents[3].contents[3].find('a').text.lstrip().rstrip()))
    except:
        list4.append('')
    try:
        list5.append(str(link.contents[3].contents[5].find('a').text.lstrip().rstrip()))
    except:
        list5.append('')
    try:
        list6.append(str(link.contents[3].contents[7].find('a').text.lstrip().rstrip()))
    except:
        list6.append('')
    try:
        list7.append(str(link.contents[3].contents[9].find('a').text.lstrip().rstrip()))
    except:
        list7.append('')
    try:
        list8.append(str(link.contents[3].contents[11].find('a').text.lstrip().rstrip()))
    except:
        list8.append('')
    try:
        list9.append(str(link.contents[3].contents[13].find('a').text.lstrip().rstrip()))
    except:
        list9.append('')
    try:
        list10.append(str(link.contents[3].contents[15].find('a').text.lstrip().rstrip()))
    except:
        list10.append('')
    
    try:
        link_introduce_data = BeautifulSoup(link_introduce.decode(), 'html.parser').find_all('p')
        s = ''
        for i in range(len(link_introduce_data)):
            s += str(link_introduce_data[i].text.lstrip().rstrip())
        list11.append(s)
    except:
        list11.append('')
    
    if len(link_others) != 0:
        try:
            link_others_data1 = BeautifulSoup(link_others[0].decode(), 'html.parser').find_all('p')
            s = ''
            for i in range(len(link_others_data1)):
                s += str(link_others_data1[i].text.lstrip().rstrip())
            list12.append(s)
        except:
            list12.append('')
        
        try:
            link_others_data2 = BeautifulSoup(link_others[1].decode(), 'html.parser').find_all('p')
            s = ''
            for i in range(len(link_others_data2)):
                s += str(link_others_data2[i].text.lstrip().rstrip())
            list13.append(s)
        except:
            list13.append('')
        
        try:
            link_others_data3 = BeautifulSoup(link_others[2].decode(), 'html.parser').find_all('p')
            s = ''
            for i in range(len(link_others_data3)):
                s += str(link_others_data3[i].text.lstrip().rstrip())
            list14.append(s)
        except:
            list14.append('')
        
        try:
            link_others_data4 = BeautifulSoup(link_others[3].decode(), 'html.parser').find_all('p')
            s = ''
            for i in range(len(link_others_data4)):
                s += str(link_others_data4[i].text.lstrip().rstrip())
            list15.append(s)
        except:
            list15.append('')
        
    else:
        list12.append('')
        list13.append('')
        list14.append('')
        list15.append('')
    
def main():
    global list4,list5,list6,list7,list8,list9,list10,list11,list12,list13,list14,list15
    list1 = []
    list2 = []
    list3 = []
    start = 11400
    last = 12000
    f = xlwt.Workbook()
    sheet1 = f.add_sheet('sheet1', cell_overwrite_ok=True)
    # Write headers to the first row of the sheet:
    sheet1.write(0, 0, "漏洞名称")
    sheet1.write(0, 1, "网址")
    sheet1.write(0, 2, "CNNVD编号")
    sheet1.write(0, 3, "危害等级")
    sheet1.write(0, 4, "CVE编号")
    sheet1.write(0, 5, "漏洞类型")
    sheet1.write(0, 6, "发布时间")
    sheet1.write(0, 7, "威胁类型")
    sheet1.write(0, 8, "更新时间")
    sheet1.write(0, 9, "厂商")
    sheet1.write(0, 10, "漏洞简介")
    sheet1.write(0, 11, "漏洞公告")
    sheet1.write(0, 12, "参考网址")
    sheet1.write(0, 13, "受影响实体")
    sheet1.write(0, 14, "补丁")
    # Loop using a range of values for j:
    for i in range(start, last+1):
        url = 'http://www.cnnvd.org.cn/web/vulnerability/querylist.tag?pageno='+str(i)+'&repairLd='
        print(f'page {i}')
        header = {
            'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/58.0.3029.110 Safari/537.3',
            'Connection': 'keep-alive'}
        r = requests.get(url, headers=header, timeout=30)
        print(r.status_code)
        html = BeautifulSoup(r.content.decode(), 'html.parser')
        link = html.find_all(class_='a_title2')
        for j in link:
            try:
                list1.append(str(j.text.lstrip().rstrip()))
                k = str(j.attrs['href'])
                list2.append('http://www.cnnvd.org.cn'+k)
                list3.append(k[28:])
                getURLDATA('http://www.cnnvd.org.cn'+k)
            except:
                print('http://www.cnnvd.org.cn'+k)
                break
    
    for i in range(1, len(list15)):
        sheet1.write(i, 0, list1[i-1])
        sheet1.write(i, 1, list2[i-1])
        sheet1.write(i, 2, list3[i-1])
        sheet1.write(i, 3, list4[i-1])
        sheet1.write(i, 4, list5[i-1])
        sheet1.write(i, 5, list6[i-1])
        sheet1.write(i, 6, list7[i-1])
        sheet1.write(i, 7, list8[i-1])
        sheet1.write(i, 8, list9[i-1])
        sheet1.write(i, 9, list10[i-1])
        sheet1.write(i, 10, list11[i-1])
        sheet1.write(i, 11, list12[i-1])
        sheet1.write(i, 12, list13[i-1])
        sheet1.write(i, 13, list14[i-1])
        sheet1.write(i, 14, list15[i-1])
    f.save('cnnvd.xls')

if __name__ == '__main__':
    main()
# Out:
# page 11400
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# File ~/anaconda3/envs/ai/lib/python3.12/site-packages/urllib3/connection.py:198, in HTTPConnection._new_conn(self)
#     197 try:
# --> 198     sock = connection.create_connection(
#     199         (self._dns_host, self.port),
#     200         self.timeout,
#     201         source_address=self.source_address,
#     202         socket_options=self.socket_options,
#     203     )
#     204 except socket.gaierror as e:
#
# File ~/anaconda3/envs/ai/lib/python3.12/site-packages/urllib3/util/connection.py:85, in create_connection(address, timeout, source_address, socket_options)
#      84 try:
# ---> 85     raise err
#      86 finally:
#      87     # Break explicitly a reference cycle
#
# File ~/anaconda3/envs/ai/lib/python3.12/site-packages/urllib3/util/connection.py:73, in create_connection(address, timeout, source_address, socket_options)
#      72     sock.bind(source_address)
# ---> 73 sock.connect(sa)
#      74 # Break explicitly a reference cycle
#
# OSError: [Errno 101] Network is unreachable
#
# The above exception was the direct cause of the following exception:
#
# NewConnectionError                        Traceback (most recent call last)
# File ~/anaconda3/envs/ai/lib/python3.12/site-packages/urllib3/connectionpool.py:793, in HTTPConnectionPool.urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, preload_content, decode_content, **response_kw)
#     792 # Make the request on the HTTPConnection object
# --> 793 response = self._make_request(
#     794     conn,
#     795     method,
#     796     url,
#     797     timeout=timeout_obj,
#     798     body=body,
#     799     headers=headers,
#     800     chunked=chunked,
#     801     retries=retries,
#     802     response_conn=response_conn,
#     803     preload_content=preload_content,
#     804     decode_content=decode_content,
#     805     **response_kw,
#     806 )
#     808 # Everything went great!
#
# File ~/anaconda3/envs/ai/lib/python3.12/site-packages/urllib3/connectionpool.py:496, in HTTPConnectionPool._make_request(self, conn, method, url, body, headers, retries, timeout, chunked, response_conn, preload_content, decode_content, enforce_content_length)
#     495 try:
# --> 496     conn.request(
#     497         method,
#     498         url,
#     499         body=body,
#     500         headers=headers,
#     501         chunked=chunked,
#     502         preload_content=preload_content,
#     503         decode_content=decode_content,
#     504         enforce_content_length=enforce_content_length,
#     505     )
#     507 # We are swallowing BrokenPipeError (errno.EPIPE) since the server is
#     508 # legitimately able to close the connection after sending a valid response.
#     509 # With this behaviour, the received response is still readable.
#
# File ~/anaconda3/envs/ai/lib/python3.12/site-packages/urllib3/connection.py:400, in HTTPConnection.request(self, method, url, body, headers, chunked, preload_content, decode_content, enforce_content_length)
#     399     self.putheader(header, value)
# --> 400 self.endheaders()
#     402 # If we're given a body we start sending that in chunks.
#
# File ~/anaconda3/envs/ai/lib/python3.12/http/client.py:1322, in HTTPConnection.endheaders(self, message_body, encode_chunked)
#    1321     raise CannotSendHeader()
# -> 1322 self._send_output(message_body, encode_chunked=encode_chunked)
#
# File ~/anaconda3/envs/ai/lib/python3.12/http/client.py:1081, in HTTPConnection._send_output(self, message_body, encode_chunked)
#    1080 del self._buffer[:]
# -> 1081 self.send(msg)
#    1083 if message_body is not None:
#    1084
#    1085     # create a consistent interface to message_body
#
# File ~/anaconda3/envs/ai/lib/python3.12/http/client.py:1025, in HTTPConnection.send(self, data)
#    1024 if self.auto_open:
# -> 1025     self.connect()
#    1026 else:
#
# File ~/anaconda3/envs/ai/lib/python3.12/site-packages/urllib3/connection.py:238, in HTTPConnection.connect(self)
#     237 def connect(self) -> None:
# --> 238     self.sock = self._new_conn()
#     239     if self._tunnel_host:
#     240         # If we're tunneling it means we're connected to our proxy.
#
# File ~/anaconda3/envs/ai/lib/python3.12/site-packages/urllib3/connection.py:213, in HTTPConnection._new_conn(self)
#     212 except OSError as e:
# --> 213     raise NewConnectionError(
#     214         self, f"Failed to establish a new connection: {e}"
#     215     ) from e
#     217 # Audit hooks are only available in Python 3.8+
#
# NewConnectionError: <urllib3.connection.HTTPConnection object at 0x7f440f281dc0>: Failed to establish a new connection: [Errno 101] Network is unreachable
#
# The above exception was the direct cause of the following exception:
#
# MaxRetryError                             Traceback (most recent call last)
# File ~/anaconda3/envs/ai/lib/python3.12/site-packages/requests/adapters.py:486, in HTTPAdapter.send(self, request, stream, timeout, verify, cert, proxies)
#     485 try:
# --> 486     resp = conn.urlopen(
#     487         method=request.method,
#     488         url=url,
#     489         body=request.body,
#     490         headers=request.headers,
#     491         redirect=False,
#     492         assert_same_host=False,
#     493         preload_content=False,
#     494         decode_content=False,
#     495         retries=self.max_retries,
#     496         timeout=timeout,
#     497         chunked=chunked,
#     498     )
#     500 except (ProtocolError, OSError) as err:
#
# File ~/anaconda3/envs/ai/lib/python3.12/site-packages/urllib3/connectionpool.py:847, in HTTPConnectionPool.urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, preload_content, decode_content, **response_kw)
#     845     new_e = ProtocolError("Connection aborted.", new_e)
# --> 847 retries = retries.increment(
#     848     method, url, error=new_e, _pool=self, _stacktrace=sys.exc_info()[2]
#     849 )
#     850 retries.sleep()
#
# File ~/anaconda3/envs/ai/lib/python3.12/site-packages/urllib3/util/retry.py:515, in Retry.increment(self, method, url, response, error, _pool, _stacktrace)
#     514     reason = error or ResponseError(cause)
# --> 515     raise MaxRetryError(_pool, url, reason) from reason  # type: ignore[arg-type]
#     517 log.debug("Incremented Retry for (url='%s'): %r", url, new_retry)
#
# MaxRetryError: HTTPConnectionPool(host='www.cnnvd.org.cn', port=80): Max retries exceeded with url: /web/vulnerability/querylist.tag?pageno=11400&repairLd= (Caused by NewConnectionError('<urllib3.connection.HTTPConnection object at 0x7f440f281dc0>: Failed to establish a new connection: [Errno 101] Network is unreachable'))
#
# During handling of the above exception, another exception occurred:
#
# ConnectionError                           Traceback (most recent call last)
# Cell In[6], line 184
#     181     f.save('cnnvd.xls')
#     183 if __name__ == '__main__':
# --> 184     main()
#
# Cell In[6], line 150, in main()
#     146 print(f'page {i}')
#     147 header = {
#     148     'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/58.0.3029.110 Safari/537.3',
#     149     'Connection': 'keep-alive'}
# --> 150 r = requests.get(url, headers=header, timeout=30)
#     151 print(r.status_code)
#     152 html = BeautifulSoup(r.content.decode(), 'html.parser')
#
# File ~/anaconda3/envs/ai/lib/python3.12/site-packages/requests/api.py:73, in get(url, params, **kwargs)
#      62 def get(url, params=None, **kwargs):
#      63     r"""Sends a GET request.
#      64
#      65     :param url: URL for the new :class:`Request` object.
#    (...)
#      70     :rtype: requests.Response
#      71     """
# ---> 73     return request("get", url, params=params, **kwargs)
#
# File ~/anaconda3/envs/ai/lib/python3.12/site-packages/requests/api.py:59, in request(method, url, **kwargs)
#      55 # By using the 'with' statement we are sure the session is closed, thus we
#      56 # avoid leaving sockets open which can trigger a ResourceWarning in some
#      57 # cases, and look like a memory leak in others.
#      58 with sessions.Session() as session:
# ---> 59     return session.request(method=method, url=url, **kwargs)
#
# File ~/anaconda3/envs/ai/lib/python3.12/site-packages/requests/sessions.py:589, in Session.request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     584 send_kwargs = {
#     585     "timeout": timeout,
#     586     "allow_redirects": allow_redirects,
#     587 }
#     588 send_kwargs.update(settings)
# --> 589 resp = self.send(prep, **send_kwargs)
#     591 return resp
#
# File ~/anaconda3/envs/ai/lib/python3.12/site-packages/requests/sessions.py:703, in Session.send(self, request, **kwargs)
#     700 start = preferred_clock()
#     702 # Send the request
# --> 703 r = adapter.send(request, **kwargs)
#     705 # Total elapsed time of the request (approximately)
#     706 elapsed = preferred_clock() - start
#
# File ~/anaconda3/envs/ai/lib/python3.12/site-packages/requests/adapters.py:519, in HTTPAdapter.send(self, request, stream, timeout, verify, cert, proxies)
#     515     if isinstance(e.reason, _SSLError):
#     516         # This branch is for urllib3 v1.22 and later.
#     517         raise SSLError(e, request=request)
# --> 519     raise ConnectionError(e, request=request)
#     521 except ClosedPoolError as e:
#     522     raise ConnectionError(e, request=request)
#
# ConnectionError: HTTPConnectionPool(host='www.cnnvd.org.cn', port=80): Max retries exceeded with url: /web/vulnerability/querylist.tag?pageno=11400&repairLd= (Caused by NewConnectionError('<urllib3.connection.HTTPConnection object at 0x7f440f281dc0>: Failed to establish a new connection: [Errno 101] Network is unreachable'))

# %%
import re

valid_tags = {
    'entry', 'name', 'vuln-id', 'published', 'modified', 'source',
    'severity', 'vuln-type', 'vuln-descript', 'other-id', 'cve-id',
    'bugtraq-id', 'vuln-solution', 'cnnvd'
}

def escape_angle_brackets(text):
    # Escaping < and > if they are not part of a valid tag
    result = ""
    tag_buffer = ""
    is_possible_tag = False

    for i, char in enumerate(text):
        if char == '<':
            is_possible_tag = True
            tag_buffer = '<'
        elif char == '>' and is_possible_tag:
            tag_buffer += '>'
            # Extract the tag name without <, /> or >
            tag_name = re.sub(r'[<\/>]', '', tag_buffer)
            if tag_name not in valid_tags:
                # Not a valid tag, escape it
                result += tag_buffer.replace('<', '&lt;').replace('>', '&gt;')
            else:
                # Valid tag, keep it
                result += tag_buffer
            tag_buffer = ""
            is_possible_tag = False
        elif is_possible_tag:
            tag_buffer += char
        else:
            if char == '<':
                result += '&lt;'
            elif char == '>':
                result += '&gt;'
            else:
                result += char

    # Append any remaining characters in the buffer
    result += tag_buffer

    return result

def escape_ampersands(text):
    # Escape ampersands that are not already part of an escape sequence
    return re.sub(r'&(?!(amp|lt|gt|quot|apos);)', '&amp;', text)

input_file = f'../data/cnnvd-data/february.xml'
output_file = f'../data/cnnvd-data/february-fixed.xml'
# Load the XML content from the file
with open(input_file, 'r', encoding='utf-8') as file:
    content = file.read()
# First, escape invalid tag brackets
content = escape_angle_brackets(content)
# Then, escape standalone ampersands
content = escape_ampersands(content)
# Write the escaped content to a new file
with open(output_file, 'w', encoding='utf-8') as file:
    file.write(content)

# %% [markdown]
# # **Analyse CNNVD database**

# %%
import pandas as pd
from tqdm import tqdm
import os

# CNNVD CSV files Path
cnnvd_csv_path = '../data/cnnvd-data/cnnvd_csv_files/'

# Load and concatenate all CSV files
for filename in tqdm(os.listdir(cnnvd_csv_path)):
    if filename.endswith('.csv'):
        if not 'cnnvd' in locals():
            cnnvd = pd.read_csv(cnnvd_csv_path + filename)
        else:
            cnnvd = pd.concat([cnnvd, pd.read_csv(cnnvd_csv_path + filename)], ignore_index=True)
# Out:
# 100%|██████████| 28/28 [00:03<00:00,  9.16it/s]

# %%
cnnvd.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 196381 entries, 0 to 196380
# Data columns (total 8 columns):
#  #   Column         Non-Null Count   Dtype
# ---  ------         --------------   -----
#  0   Name           196381 non-null  object
#  1   Vuln ID        196381 non-null  object
#  2   Published      196381 non-null  object
#  3   Modified       196381 non-null  object
#  4   Severity       188873 non-null  object
#  5   Vuln Type      196381 non-null  object
#  6   Vuln Descript  196378 non-null  object
#  7   CVE ID         186417 non-null  object
# dtypes: object(8)
# memory usage: 12.0+ MB

# %%
cnnvd.describe()
# Out:
#                      Name            Vuln ID   Published    Modified Severity  \
# count              196381             196381      196381      196381   188873
# unique             119616             186711        7363        4404        4
# top     Linux kernel 安全漏洞  CNNVD-202402-1896  1900-01-01  2005-10-20       中危
# freq                 1672                  4        2255        7071    85244
#
#        Vuln Type                       Vuln Descript         CVE ID
# count     196381                              196378         186417
# unique        26                              170808         176730
# top         授权问题  此编号已经被分配用于标识某安全漏洞，出于安全考虑，漏洞详情暂不公开。  CVE-2024-0763
# freq       62963                                3685              4

# %%
from google.cloud import translate_v2 as translate
import pandas as pd
from tqdm.auto import tqdm
tqdm.pandas()

# Initialize the Google Cloud Translation client with your project ID
translate_client = translate.Client()

def translate_text(text, target_language='en'):
    """Translate the given text to the target language."""
    if text and text.strip():
        # Translate the text and return the translated text
        translation = translate_client.translate(text, target_language=target_language)
        print(translation['translatedText'])
        return translation['translatedText']
    return text  # Return the original text if it's empty or whitespace

def translate_column(input_file, output_file, column_name, target_language='en'):
    """Translate a specific column in a CSV file and save the results after completion."""
    df = pd.read_csv(input_file, encoding='utf-8')

    # Check if the column exists in the DataFrame
    if column_name not in df.columns:
        raise ValueError(f"Column '{column_name}' does not exist in the DataFrame.")

    # Translate only the specified column
    df[column_name] = df[column_name].astype(str).progress_apply(lambda text: translate_text(text, target_language))

    # Save the file after the entire column is translated
    df.to_csv(output_file, index=False, encoding='utf-8')

# Specify the input file, output file, the column to translate, and the target language
translate_column('../data/cnnvd-data/cnnvd_data_12_03_24.csv', '../data/cnnvd-data/cnnvd_data_translated.csv', 'Vuln Descript', 'en')


# Replace 'path/to/your/file.csv' with the path to your CSV file
#ranslate_csv('../data/cnnvd-data/cnnvd_data_12_03_24.csv')
# Out:
#   0%|          | 0/196381 [00:00<?, ?it/s]
# Opera is a web browser developed by the Norwegian company Opera Software. It supports multi-window browsing, customizable user interface, etc. There is a vulnerability in Opera versions before 12.12. Through high-rate HTTP requests, remote attackers can exploit this vulnerability to forge the address bar.
# MoinMoin is a set of open source, extensible wiki engine programs based on Python environment. There is a cross-site scripting vulnerability in the rsslink function in theme/__init__.py in MoinMoin version 1.9.5. A remote attacker could exploit this vulnerability to inject arbitrary web script or HTML via the page name in the RSS link.
# MediaWiki is a set of free and free network-based Wiki engines jointly developed and maintained by the American Wikimedia Foundation and MediaWiki volunteers. It can be used to deploy internal knowledge management and content management systems. There is a cross-site scripting vulnerability in the RSS Reader extension in MediaWiki before version 0.2.6. Through a specially crafted subscription, a remote attacker could exploit this vulnerability to inject arbitrary web script or HTML.
# Samsung Galaxy is a series of smart mobile devices released by South Korea&#39;s Samsung Company. A vulnerability exists in the Track My Mobile functionality in the SamsungDive subsystem of the Android system of Samsung Galaxy devices. The vulnerability results from the program not correctly implementing Location APIs. A physically proximate attacker could exploit this vulnerability to provide arbitrary location data via a &#39;common and easy-to-use GPS location spoofer&#39;.
# Lookout is a set of applications for tracking and positioning mobile phones on the Android platform. There is a vulnerability in the Missing Device feature in Lookout. Through a &#39;common and easy-to-use GPS location spoof&#39;, a physically proximate attacker could exploit this vulnerability to provide arbitrary location data.
# Opera is a web browser developed by the Norwegian company Opera Software. It supports multi-window browsing, customizable user interface, etc. The vulnerability exists in Opera versions before 11.67 and 12.x versions before 12.02. Through a specially crafted website, a remote attacker could exploit this vulnerability to cause session truncation, potentially triggering the download and execution of arbitrary programs.
# MoinMoin is a set of open source, extensible wiki engine programs based on Python environment. There is a directory traversal vulnerability in the _do_attachment_move function in the AttachFile operation (action/AttachFile.py) in MoinMoin versions 1.9.3 to 1.9.5. A remote attacker could exploit this vulnerability to overwrite arbitrary files via a &#39;..&#39; in the file name.
# MoinMoin is a set of open source, extensible wiki engine programs based on Python environment. Multiple unrestricted file upload vulnerabilities exist in the (1) twikidraw(action/twikidraw.py) and (2) anywikidraw(action/anywikidraw.py) operations in MoinMoin versions prior to 1.9.6. A remote authenticated attacker could exploit these vulnerabilities to execute arbitrary code with write permissions by uploading an executable file and subsequently sending a direct access request to it.
# Opera is a web browser developed by the Norwegian company Opera Software. It supports multi-window browsing, customizable user interface, etc. There is a vulnerability in Opera versions before 12.10. A remote attacker could exploit this vulnerability to execute arbitrary code or cause a denial of service (application crash) via a malformed SVG image.
# WordPress is a blogging platform developed using the PHP language by the WordPress Software Foundation. The platform supports setting up personal blog websites on PHP and MySQL servers. There is a vulnerability in the wp-php-widget.php script in version 1.0.2 of the WP PHP widget plugin in WordPress. A remote attacker could exploit this vulnerability to obtain sensitive information via a direct request that reveals the full path in the error message.
# Samsung Galaxy is a series of smart mobile devices released by South Korea&#39;s Samsung Company. A vulnerability exists in the Track My Mobile functionality in the SamsungDive subsystem of the Android system of Samsung Galaxy devices. The vulnerability stems from the program displaying remote tracking activation information. A physically proximate attacker could exploit this vulnerability to disable the factory reset functionality by tampering with this feature or its location data.
# Opera is a web browser developed by the Norwegian company Opera Software. It supports multi-window browsing, customizable user interface, etc. A vulnerability exists in versions of Opera prior to 12.12, which results from not properly allocating memory for GIF images. Through a malformed image, a remote attacker could exploit this vulnerability to execute arbitrary code or cause a denial of service (memory overwrite).
# Drupal is a free, open source content management system developed in PHP language maintained by the Drupal community. Nodewords in Drupal: There is a vulnerability in the D6 Meta Tags module before version 6.x-1.14. When it is set to automatically generate description meta tags from node text, the program does not correctly filter node content when creating new tags. A remote attacker could exploit this vulnerability to obtain sensitive information by reading the (1) description (2) dc.description or (3) og:description meta tag.
# Drupal is a free, open source content management system developed in PHP language maintained by the Drupal community. A vulnerability exists in the file upload functionality in Drupal 6.x versions prior to 6.27 and 7.x versions prior to 7.18. A remote authenticated attacker could exploit this vulnerability to bypass protection mechanisms and execute arbitrary PHP code via null bytes in the file name.
# Opera is a web browser developed by the Norwegian company Opera Software. It supports multi-window browsing, customizable user interface, etc. A cross-site scripting vulnerability exists in Opera versions prior to 12.10. A remote attacker can exploit this vulnerability to inject arbitrary web script or HTML by overwriting methods of unspecified local objects in documents from different sources by using specially crafted JavaScript code.
# IBM SPSS Modeler (formerly known as Clementine) is a data mining platform from IBM in the United States. The platform provides a visual environment for quickly building models, and provides functions such as data source connection, data processing, and modeling analysis. There is a vulnerability in IBM SPSS Modeler 14.0, 14.1, 14.2 to FP3 versions and 15.0 versions before FP2. By combining an XML external entity declaration with an entity reference, a remote attacker could exploit this vulnerability to read arbitrary files, potentially making HTTP requests to a LAN server or causing a denial of service (CPU and memory consumption).
# AVG AntiVirus for Android is an antivirus and anti-backdoor program for smartphones. There is a vulnerability in the Anti-theft service of AVG AntiVirus on Android. A physically proximate attacker could exploit this vulnerability to provide arbitrary location data via a &#39;common and easy-to-use GPS location spoofer&#39;.
# Drupal is a free, open source content management system developed in PHP language maintained by the Drupal community. There is a vulnerability in the Context module in Drupal in 6.x-3.x versions before 6.x-3.1 and 7.x-3.x versions before 7.x-3.0-beta6. The vulnerability is due to incorrect Block content and set access restrictions. A remote attacker could exploit this vulnerability to obtain sensitive information via a specially crafted request.
# Opera is a web browser developed by the Norwegian company Opera Software. It supports multi-window browsing, customizable user interface, etc. There is a vulnerability in versions of Opera before 12.12 based on UNIX systems. The vulnerability is caused by the use of weak permissions in the configuration directory. A local attacker could exploit this vulnerability to obtain sensitive information by reading (1) cache files (2) password files or (3) configuration files or (4) gain privileges by modifying or rewriting configuration files.
# There is a cross-site scripting vulnerability in the network management interface of Polycom HDX Video End Points with UC APL software versions prior to 2.7.1.1_J and business software versions prior to 3.0.5. Through unspecified vectors, a remote attacker can exploit this vulnerability to inject arbitrary web script or HTML.
# Belkin N900 F9K1104v1 is a wireless router product from Belkin Company of the United States. There is a vulnerability in the WPA2 implementation based on the Belkin N900 F9K1104v1 router. The vulnerability stems from the program creating a WPS PIN based on 6 digits of the LAN/WLAN MAC address. By reading broadcast messages, a remote attacker can exploit this vulnerability to gain access to the Wi-Fi network.
# ircd-ratbox is an online instant chat service program. A vulnerability exists in modules/m_capab.c in ircd-ratbox versions prior to 3.0.8 and Charybdis versions prior to 3.4.2. The vulnerability is caused by failure to properly support capability negotiation during the server handshake. Through malicious requests, a remote attacker could exploit this vulnerability to cause a denial of service (null pointer reference and daemon crash).
# e107 is an open source, free content management system (CMS) based on PHP and MySQL developed by the e107 team. The system supports a variety of plug-ins and appearance themes, and can be used as a personal blog, discussion community, archive database, etc. A cross-site request forgery vulnerability exists in the e107_admin/newspost.php script in e107 version 1.0.1. By creating the news_title parameter in the operation, a remote attacker can exploit this vulnerability to hijack administrator authentication requests and conduct XSS (cross-site scripting) attacks.
# vBulletin is an open source commercial Web forum program jointly developed by Internet Brands and vBulletin Solutions in the United States. An open redirect vulnerability exists in the forum/login.php script in vBulletin 4.1.3 and earlier versions. Through the url parameter in the lostpw operation, a remote attacker can use this vulnerability to redirect users to any website to conduct phishing attacks.
# Opera is a web browser developed by the Norwegian company Opera Software. It supports multi-window browsing, customizable user interface, etc. A heap-based buffer overflow vulnerability exists in Opera versions prior to 12.11. Through a long HTTP response, a remote attacker could exploit this vulnerability to execute arbitrary code or cause a denial of service (memory corruption).
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[4], line 33
#      30     df.to_csv(output_file, index=False, encoding='utf-8')
#      32 # Specify the input file, output file, the column to translate, and the target language
# ---> 33 translate_column('../data/cnnvd-data/cnnvd_data_12_03_24.csv', '../data/cnnvd-data/cnnvd_data_translated.csv', 'Vuln Descript', 'en')
#      36 # Replace 'path/to/your/file.csv' with the path to your CSV file
#      37 #ranslate_csv('../data/cnnvd-data/cnnvd_data_12_03_24.csv')
#
# Cell In[4], line 27, in translate_column(input_file, output_file, column_name, target_language)
#      24     raise ValueError(f"Column '{column_name}' does not exist in the DataFrame.")
#      26 # Translate only the specified column
# ---> 27 df[column_name] = df[column_name].astype(str).progress_apply(lambda text: translate_text(text, target_language))
#      29 # Save the file after the entire column is translated
#      30 df.to_csv(output_file, index=False, encoding='utf-8')
#
# File ~/anaconda3/envs/ai/lib/python3.11/site-packages/tqdm/std.py:805, in tqdm.pandas.<locals>.inner_generator.<locals>.inner(df, func, *args, **kwargs)
#     802 # Apply the provided function (in **kwargs)
#     803 # on the df using our wrapper (which provides bar updating)
#     804 try:
# --> 805     return getattr(df, df_function)(wrapper, **kwargs)
#     806 finally:
#     807     t.close()
#
# File ~/anaconda3/envs/ai/lib/python3.11/site-packages/pandas/core/series.py:4764, in Series.apply(self, func, convert_dtype, args, by_row, **kwargs)
#    4629 def apply(
#    4630     self,
#    4631     func: AggFuncType,
#    (...)
#    4636     **kwargs,
#    4637 ) -> DataFrame | Series:
#    4638     """
#    4639     Invoke function on values of Series.
#    4640
#    (...)
#    4755     dtype: float64
#    4756     """
#    4757     return SeriesApply(
#    4758         self,
#    4759         func,
#    4760         convert_dtype=convert_dtype,
#    4761         by_row=by_row,
#    4762         args=args,
#    4763         kwargs=kwargs,
# -> 4764     ).apply()
#
# File ~/anaconda3/envs/ai/lib/python3.11/site-packages/pandas/core/apply.py:1209, in SeriesApply.apply(self)
#    1206     return self.apply_compat()
#    1208 # self.func is Callable
# -> 1209 return self.apply_standard()
#
# File ~/anaconda3/envs/ai/lib/python3.11/site-packages/pandas/core/apply.py:1289, in SeriesApply.apply_standard(self)
#    1283 # row-wise access
#    1284 # apply doesn't have a `na_action` keyword and for backward compat reasons
#    1285 # we need to give `na_action="ignore"` for categorical data.
#    1286 # TODO: remove the `na_action="ignore"` when that default has been changed in
#    1287 #  Categorical (GH51645).
#    1288 action = "ignore" if isinstance(obj.dtype, CategoricalDtype) else None
# -> 1289 mapped = obj._map_values(
#    1290     mapper=curried, na_action=action, convert=self.convert_dtype
#    1291 )
#    1293 if len(mapped) and isinstance(mapped[0], ABCSeries):
#    1294     # GH#43986 Need to do list(mapped) in order to get treated as nested
#    1295     #  See also GH#25959 regarding EA support
#    1296     return obj._constructor_expanddim(list(mapped), index=obj.index)
#
# File ~/anaconda3/envs/ai/lib/python3.11/site-packages/pandas/core/base.py:921, in IndexOpsMixin._map_values(self, mapper, na_action, convert)
#     918 if isinstance(arr, ExtensionArray):
#     919     return arr.map(mapper, na_action=na_action)
# --> 921 return algorithms.map_array(arr, mapper, na_action=na_action, convert=convert)
#
# File ~/anaconda3/envs/ai/lib/python3.11/site-packages/pandas/core/algorithms.py:1814, in map_array(arr, mapper, na_action, convert)
#    1812 values = arr.astype(object, copy=False)
#    1813 if na_action is None:
# -> 1814     return lib.map_infer(values, mapper, convert=convert)
#    1815 else:
#    1816     return lib.map_infer_mask(
#    1817         values, mapper, mask=isna(values).view(np.uint8), convert=convert
#    1818     )
#
# File lib.pyx:2926, in pandas._libs.lib.map_infer()
#
# File ~/anaconda3/envs/ai/lib/python3.11/site-packages/tqdm/std.py:800, in tqdm.pandas.<locals>.inner_generator.<locals>.inner.<locals>.wrapper(*args, **kwargs)
#     794 def wrapper(*args, **kwargs):
#     795     # update tbar correctly
#     796     # it seems `pandas apply` calls `func` twice
#     797     # on the first column/row to decide whether it can
#     798     # take a fast or slow code path; so stop when t.total==t.n
#     799     t.update(n=1 if not t.total or t.n < t.total else 0)
# --> 800     return func(*args, **kwargs)
#
# Cell In[4], line 27, in translate_column.<locals>.<lambda>(text)
#      24     raise ValueError(f"Column '{column_name}' does not exist in the DataFrame.")
#      26 # Translate only the specified column
# ---> 27 df[column_name] = df[column_name].astype(str).progress_apply(lambda text: translate_text(text, target_language))
#      29 # Save the file after the entire column is translated
#      30 df.to_csv(output_file, index=False, encoding='utf-8')
#
# Cell In[4], line 13, in translate_text(text, target_language)
#      10 """Translate the given text to the target language."""
#      11 if text and text.strip():
#      12     # Translate the text and return the translated text
# ---> 13     translation = translate_client.translate(text, target_language=target_language)
#      14     print(translation['translatedText'])
#      15     return translation['translatedText']
#
# File ~/anaconda3/envs/ai/lib/python3.11/site-packages/google/cloud/translate_v2/client.py:265, in Client.translate(self, values, target_language, format_, source_language, customization_ids, model)
#     254     customization_ids = [customization_ids]
#     256 data = {
#     257     "target": target_language,
#     258     "q": values,
#    (...)
#     262     "model": model,
#     263 }
# --> 265 response = self._connection.api_request(method="POST", path="", data=data)
#     267 translations = response.get("data", {}).get("translations", ())
#     268 if len(values) != len(translations):
#
# File ~/anaconda3/envs/ai/lib/python3.11/site-packages/google/cloud/_http/__init__.py:482, in JSONConnection.api_request(self, method, path, query_params, data, content_type, headers, api_base_url, api_version, expect_json, _target_object, timeout, extra_api_info)
#     479     data = json.dumps(data)
#     480     content_type = "application/json"
# --> 482 response = self._make_request(
#     483     method=method,
#     484     url=url,
#     485     data=data,
#     486     content_type=content_type,
#     487     headers=headers,
#     488     target_object=_target_object,
#     489     timeout=timeout,
#     490     extra_api_info=extra_api_info,
#     491 )
#     493 if not 200 <= response.status_code < 300:
#     494     raise exceptions.from_http_response(response)
#
# File ~/anaconda3/envs/ai/lib/python3.11/site-packages/google/cloud/_http/__init__.py:341, in JSONConnection._make_request(self, method, url, data, content_type, headers, target_object, timeout, extra_api_info)
#     338     headers[CLIENT_INFO_HEADER] = self.user_agent
#     339 headers["User-Agent"] = self.user_agent
# --> 341 return self._do_request(
#     342     method, url, headers, data, target_object, timeout=timeout
#     343 )
#
# File ~/anaconda3/envs/ai/lib/python3.11/site-packages/google/cloud/_http/__init__.py:379, in JSONConnection._do_request(self, method, url, headers, data, target_object, timeout)
#     345 def _do_request(
#     346     self, method, url, headers, data, target_object, timeout=_DEFAULT_TIMEOUT
#     347 ):  # pylint: disable=unused-argument
#     348     """Low-level helper:  perform the actual API request over HTTP.
#     349
#     350     Allows batch context managers to override and defer a request.
#    (...)
#     377     :returns: The HTTP response.
#     378     """
# --> 379     return self.http.request(
#     380         url=url, method=method, headers=headers, data=data, timeout=timeout
#     381     )
#
# File ~/anaconda3/envs/ai/lib/python3.11/site-packages/google/auth/transport/requests.py:549, in AuthorizedSession.request(self, method, url, data, headers, max_allowed_time, timeout, **kwargs)
#     546 remaining_time = guard.remaining_timeout
#     548 with TimeoutGuard(remaining_time) as guard:
# --> 549     response = super(AuthorizedSession, self).request(
#     550         method,
#     551         url,
#     552         data=data,
#     553         headers=request_headers,
#     554         timeout=timeout,
#     555         **kwargs
#     556     )
#     557 remaining_time = guard.remaining_timeout
#     559 # If the response indicated that the credentials needed to be
#     560 # refreshed, then refresh the credentials and re-attempt the
#     561 # request.
#     562 # A stored token may expire between the time it is retrieved and
#     563 # the time the request is made, so we may need to try twice.
#
# File ~/anaconda3/envs/ai/lib/python3.11/site-packages/requests/sessions.py:589, in Session.request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     584 send_kwargs = {
#     585     "timeout": timeout,
#     586     "allow_redirects": allow_redirects,
#     587 }
#     588 send_kwargs.update(settings)
# --> 589 resp = self.send(prep, **send_kwargs)
#     591 return resp
#
# File ~/anaconda3/envs/ai/lib/python3.11/site-packages/requests/sessions.py:703, in Session.send(self, request, **kwargs)
#     700 start = preferred_clock()
#     702 # Send the request
# --> 703 r = adapter.send(request, **kwargs)
#     705 # Total elapsed time of the request (approximately)
#     706 elapsed = preferred_clock() - start
#
# File ~/anaconda3/envs/ai/lib/python3.11/site-packages/requests/adapters.py:486, in HTTPAdapter.send(self, request, stream, timeout, verify, cert, proxies)
#     483     timeout = TimeoutSauce(connect=timeout, read=timeout)
#     485 try:
# --> 486     resp = conn.urlopen(
#     487         method=request.method,
#     488         url=url,
#     489         body=request.body,
#     490         headers=request.headers,
#     491         redirect=False,
#     492         assert_same_host=False,
#     493         preload_content=False,
#     494         decode_content=False,
#     495         retries=self.max_retries,
#     496         timeout=timeout,
#     497         chunked=chunked,
#     498     )
#     500 except (ProtocolError, OSError) as err:
#     501     raise ConnectionError(err, request=request)
#
# File ~/anaconda3/envs/ai/lib/python3.11/site-packages/urllib3/connectionpool.py:715, in HTTPConnectionPool.urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     712     self._prepare_proxy(conn)
#     714 # Make the request on the httplib connection object.
# --> 715 httplib_response = self._make_request(
#     716     conn,
#     717     method,
#     718     url,
#     719     timeout=timeout_obj,
#     720     body=body,
#     721     headers=headers,
#     722     chunked=chunked,
#     723 )
#     725 # If we're going to release the connection in ``finally:``, then
#     726 # the response doesn't need to know about the connection. Otherwise
#     727 # it will also try to release it and we'll have a double-release
#     728 # mess.
#     729 response_conn = conn if not release_conn else None
#
# File ~/anaconda3/envs/ai/lib/python3.11/site-packages/urllib3/connectionpool.py:467, in HTTPConnectionPool._make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     462             httplib_response = conn.getresponse()
#     463         except BaseException as e:
#     464             # Remove the TypeError from the exception chain in
#     465             # Python 3 (including for exceptions like SystemExit).
#     466             # Otherwise it looks like a bug in the code.
# --> 467             six.raise_from(e, None)
#     468 except (SocketTimeout, BaseSSLError, SocketError) as e:
#     469     self._raise_timeout(err=e, url=url, timeout_value=read_timeout)
#
# File <string>:3, in raise_from(value, from_value)
#
# File ~/anaconda3/envs/ai/lib/python3.11/site-packages/urllib3/connectionpool.py:462, in HTTPConnectionPool._make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     459 except TypeError:
#     460     # Python 3
#     461     try:
# --> 462         httplib_response = conn.getresponse()
#     463     except BaseException as e:
#     464         # Remove the TypeError from the exception chain in
#     465         # Python 3 (including for exceptions like SystemExit).
#     466         # Otherwise it looks like a bug in the code.
#     467         six.raise_from(e, None)
#
# File ~/anaconda3/envs/ai/lib/python3.11/http/client.py:1378, in HTTPConnection.getresponse(self)
#    1376 try:
#    1377     try:
# -> 1378         response.begin()
#    1379     except ConnectionError:
#    1380         self.close()
#
# File ~/anaconda3/envs/ai/lib/python3.11/http/client.py:318, in HTTPResponse.begin(self)
#     316 # read until we get a non-100 response
#     317 while True:
# --> 318     version, status, reason = self._read_status()
#     319     if status != CONTINUE:
#     320         break
#
# File ~/anaconda3/envs/ai/lib/python3.11/http/client.py:279, in HTTPResponse._read_status(self)
#     278 def _read_status(self):
# --> 279     line = str(self.fp.readline(_MAXLINE + 1), "iso-8859-1")
#     280     if len(line) > _MAXLINE:
#     281         raise LineTooLong("status line")
#
# File ~/anaconda3/envs/ai/lib/python3.11/socket.py:706, in SocketIO.readinto(self, b)
#     704 while True:
#     705     try:
# --> 706         return self._sock.recv_into(b)
#     707     except timeout:
#     708         self._timeout_occurred = True
#
# File ~/anaconda3/envs/ai/lib/python3.11/ssl.py:1311, in SSLSocket.recv_into(self, buffer, nbytes, flags)
#    1307     if flags != 0:
#    1308         raise ValueError(
#    1309           "non-zero flags not allowed in calls to recv_into() on %s" %
#    1310           self.__class__)
# -> 1311     return self.read(nbytes, buffer)
#    1312 else:
#    1313     return super().recv_into(buffer, nbytes, flags)
#
# File ~/anaconda3/envs/ai/lib/python3.11/ssl.py:1167, in SSLSocket.read(self, len, buffer)
#    1165 try:
#    1166     if buffer is not None:
# -> 1167         return self._sslobj.read(len, buffer)
#    1168     else:
#    1169         return self._sslobj.read(len)
#
# KeyboardInterrupt:

# %%
output_file
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 output_file
#
# NameError: name 'output_file' is not defined

# %%
cnnvd.head()
# Out:
#                                               Name           Vuln ID  \
# 0                                       Opera 安全漏洞  CNNVD-201301-023
# 1     MoinMoin ‘theme/__init__.py’ rsslink函数跨站脚本漏洞  CNNVD-201301-031
# 2                     MediaWiki RSS Reader扩展跨站脚本漏洞  CNNVD-201301-005
# 3  Samsung Galaxy Android设备Track My Mobile功能设计错误漏洞  CNNVD-201301-001
# 4                     Lookout Missing Device功能安全漏洞  CNNVD-201301-003
#
#     Published    Modified Severity Vuln Type  \
# 0  2013-01-04  2013-01-04       中危        其他
# 1  2013-01-04  2013-01-04       中危      跨站脚本
# 2  2013-01-04  2013-01-04       中危      跨站脚本
# 3  2013-01-04  2013-01-08       低危      授权问题
# 4  2013-01-04  2013-01-08       低危      授权问题
#
#                                        Vuln Descript         CVE ID
# 0  Opera是挪威欧朋（Opera Software）公司所开发的一款Web浏览器，它支持多窗...  CVE-2012-6471
# 1  MoinMoin是一套开源的、可扩展的基于Python环境的wiki引擎程序。 MoinMo...  CVE-2012-6082
# 2  MediaWiki是美国维基媒体（Wikimedia）基金会和MediaWiki志愿者共同开...  CVE-2012-6453
# 3  Samsung Galaxy是韩国三星（Samsung）公司发布的系列智能移动设备。 Sam...  CVE-2012-6334
# 4  Lookout是一套用于安卓平台下可对手机进行跟踪定位的应用。 Lookout中的Missi...  CVE-2012-6336

# %%
# Get unique values of the 'vuln-id' column
cnnvd['Vuln ID'].nunique()
# Out:
# 186711

# %%
# Get rows with duplicate 'vuln-id' values
cnnvd[cnnvd.duplicated(subset='Vuln ID', keep=False)].sort_values(by='Vuln ID')
# Out:
#                                  Name           Vuln ID   Published  \
# 42045                  libxml2 数字错误漏洞  CNNVD-200312-487  2003-12-31
# 90164                  libxml2 数字错误漏洞  CNNVD-200312-487  2003-12-31
# 43368       Fidra Lighthouse CMS 安全漏洞  CNNVD-200512-736  2005-12-31
# 157757      Fidra Lighthouse CMS 安全漏洞  CNNVD-200512-736  2005-12-31
# 41011   X.Org setuid调用返回检查 多个本地权限提升漏洞  CNNVD-200606-318  2006-06-15
# ...                               ...               ...         ...
# 180655                  bpftrace 安全漏洞  CNNVD-202403-802  2024-03-10
# 26936    BPF Compiler Collection 安全漏洞  CNNVD-202403-803  2024-03-10
# 181120   BPF Compiler Collection 安全漏洞  CNNVD-202403-803  2024-03-10
# 26533                 Musicshelf 安全漏洞  CNNVD-202403-804  2024-03-10
# 180717                Musicshelf 安全漏洞  CNNVD-202403-804  2024-03-10
#
#           Modified Severity Vuln Type  \
# 42045   2024-02-04       中危      数字错误
# 90164   2024-02-04       中危      数字错误
# 43368   2024-02-20       低危        其他
# 157757  2024-02-20       低危        其他
# 41011   2024-01-23       低危      授权问题
# ...            ...      ...       ...
# 180655  2024-03-11       高危        其他
# 26936   2024-03-11       中危        其他
# 181120  2024-03-11       中危        其他
# 26533   2024-03-11       低危        其他
# 180717  2024-03-11       低危        其他
#
#                                             Vuln Descript         CVE ID
# 42045   libxml2是开源的一个用来解析XML文档的函数库。它用C语言写成，并且能为多种语言所调用...  CVE-2003-1564
# 90164   libxml2是开源的一个用来解析XML文档的函数库。它用C语言写成，并且能为多种语言所调用...  CVE-2003-1564
# 43368   Fidra Lighthouse CMS 1.1.0及更早版本中存在安全漏洞，远程攻击者可以...  CVE-2005-4780
# 157757  Fidra Lighthouse CMS 1.1.0及更早版本中存在安全漏洞，远程攻击者可以...  CVE-2005-4780
# 41011   X.Org是X.Org基金会运作的一个对X Window系统的官方参考实现，是开源的自由软件...  CVE-2006-2916
# ...                                                   ...            ...
# 180655  bpftrace是一种高级跟踪语言，适用于最新 Linux 内核 (4.x) 中提供的 Li...  CVE-2024-2313
# 26936   BPF Compiler Collection是一个用于创建高效的内核跟踪和操作程序的工具包...  CVE-2024-2314
# 181120  BPF Compiler Collection是一个用于创建高效的内核跟踪和操作程序的工具包...  CVE-2024-2314
# 26533   Musicshelf是RedNesto个人开发者的一款音乐架软件。用于帮助管理乐谱（和各种相...  CVE-2024-2365
# 180717  Musicshelf是RedNesto个人开发者的一款音乐架软件。用于帮助管理乐谱（和各种相...  CVE-2024-2365
#
# [16935 rows x 8 columns]

# %%
# Remove duplicate rows
cnnvd = cnnvd.drop_duplicates(subset=['Vuln ID'])

# %%
cnnvd.describe()
# Out:
#                      Name           Vuln ID   Published    Modified Severity  \
# count              186711            186711      186711      186711   179623
# unique             119614            186711        7363        4404        4
# top     Linux kernel 安全漏洞  CNNVD-201301-023  1900-01-01  2005-10-20       中危
# freq                  859                 1        2255        7071    79686
#
#        Vuln Type                       Vuln Descript         CVE ID
# count     186711                              186708         176747
# unique        26                              170805         176730
# top         授权问题  此编号已经被分配用于标识某安全漏洞，出于安全考虑，漏洞详情暂不公开。  CVE-2019-3901
# freq       62644                                3685              2

# %%
# Get the number of rows with cve-id values is null
cnnvd['CVE ID'].isnull().sum()
# Out:
# 9964
